# %%
import requests

# %%
books = requests.get('http://openlibrary.org/search.json?q=the+lord+of+the+rings')

# %% [markdown]
# Let's start by exploring the data. Take a look at the openlibrary api response to understand its structure and any patterns or anomalies. What insights can you gather from an initial examination?
#
# The next step is to convert the json to tabular format.

# %%
books.json()
